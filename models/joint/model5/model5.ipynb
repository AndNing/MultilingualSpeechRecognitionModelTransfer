# %%
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# %%
# !cp '/content/drive/MyDrive/spectrograms.zip' .

# %%
# !unzip -q spectrograms.zip

# %%
# !pip list

# %%
# !rm -r /content/logs

# %%
import keras.callbacks
import tensorflow as tf
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from tensorflow.keras.utils import Sequence
import math
import pandas as pd
import random
from tensorflow.keras import models, layers, callbacks, activations

import librosa
import librosa.display

import warnings

import pickle

AUTOTUNE = tf.data.AUTOTUNE

# tf.config.run_functions_eagerly(True)

# %%
RUN = '2'

SAMPLE_RATE = 24000
FREQ_SIZE = 188
SECONDS = 4

N_MFCC = 100

BATCH_SIZE_TRAIN = 25
BATCH_SIZE_TEST = 1
BATCH_SIZE_VAL = 50
EPOCHS = 100

NUM_TRAIN = 900
NUM_VAL = 500
NUM_TEST = 250

STEPS_PER_EPOCH = NUM_TRAIN // BATCH_SIZE_TRAIN

NUM_LANGUAGES = 5
LANGUAGES = ['EN','ES','FR','DE','CA']

LOG_DIR = "logs/model" + str(NUM_LANGUAGES) + "-"

SEED = 0
tf.random.set_seed(SEED)
np.random.seed(SEED)

LEARNING_RATE = 0.0001

# %%
BASE_DIR_EN = '../../../spectrograms/en/clips/'
TRAIN_PATH_EN = '../../../spectrograms/en/train.tsv'
TEST_PATH_EN = '../../../spectrograms/en/test.tsv'
VAL_PATH_EN = '../../../spectrograms/en/val.tsv'

NUM_TRAIN_EN = NUM_TRAIN
NUM_VAL_EN = NUM_VAL
NUM_TEST_EN = NUM_TEST

LABELS_EN = ['zero','one','two','three','four','five','six','seven','eight','nine','ten','Hey','yes','no','Firefox']
NUM_LABELS_EN = len(LABELS_EN)

# %%
BASE_DIR_ES = '../../../spectrograms/es/clips/'
TRAIN_PATH_ES = '../../../spectrograms/es/train.tsv'
TEST_PATH_ES = '../../../spectrograms/es/test.tsv'
VAL_PATH_ES = '../../../spectrograms/es/val.tsv'

NUM_TRAIN_ES = NUM_TRAIN
NUM_VAL_ES = NUM_VAL
NUM_TEST_ES = NUM_TEST

LABELS_ES = ['cero','cinco','cuatro','dos','Firefox','Hey','no','neuve','ocho','seis','siete','tres','uno','sí']
NUM_LABELS_ES = len(LABELS_ES)

# %%
BASE_DIR_FR = '../../../spectrograms/fr/clips/'
TRAIN_PATH_FR = '../../../spectrograms/fr/train.tsv'
TEST_PATH_FR = '../../../spectrograms/fr/test.tsv'
VAL_PATH_FR = '../../../spectrograms/fr/val.tsv'

NUM_TRAIN_FR = NUM_TRAIN
NUM_VAL_FR = NUM_VAL
NUM_TEST_FR = NUM_TEST

LABELS_FR = ['zéro','un','deux','trois','quatre','cinq','six','sept','huit','neuf','dix','Hey','oui','non','Firefox']
NUM_LABELS_FR = len(LABELS_FR)

# %%
BASE_DIR_DE = '../../../spectrograms/de/clips/'
TRAIN_PATH_DE = '../../../spectrograms/de/train.tsv'
TEST_PATH_DE = '../../../spectrograms/de/test.tsv'
VAL_PATH_DE = '../../../spectrograms/de/val.tsv'

NUM_TRAIN_DE = NUM_TRAIN
NUM_VAL_DE = NUM_VAL
NUM_TEST_DE = NUM_TEST

LABELS_DE = ['zwei','vier','sieben','sechs','neun','nein','nan','ja','fünf','eins','drei','acht','Hey','Hei','Firefox']
NUM_LABELS_DE = len(LABELS_DE)

# %%
BASE_DIR_CA = '../../../spectrograms/ca/clips/'
TRAIN_PATH_CA = '../../../spectrograms/ca/train.tsv'
TEST_PATH_CA = '../../../spectrograms/ca/test.tsv'
VAL_PATH_CA = '../../../spectrograms/ca/val.tsv'

NUM_TRAIN_CA = NUM_TRAIN
NUM_VAL_CA = NUM_VAL
NUM_TEST_CA = NUM_TEST

LABELS_CA = ['Ei','Firefox','cinc','dos','no','nou','quatre','set','sis','sí','tres','u','vuit','zero']
NUM_LABELS_CA = len(LABELS_CA)

# %%
def padaudio(waveform):
    if (len(waveform) >= SAMPLE_RATE * SECONDS):
        return waveform
    else:
        return np.pad(waveform,(0,SAMPLE_RATE * SECONDS - len(waveform)),mode='constant', constant_values=(0,0))

# def processdata(file):
#     waveform,sample_rate = librosa.load(file, SAMPLE_RATE)
#     waveform = padaudio(waveform)
#     mfccs = librosa.feature.mfcc(waveform,sr=sample_rate,n_mfcc=N_MFCC)
#     mfccs = np.moveaxis(mfccs,1,0)
#     scaler = StandardScaler()
#     mfccs_scaled = scaler.fit_transform(mfccs)
#     return mfccs_scaled.reshape(mfccs_scaled.shape[0], mfccs_scaled.shape[1],1)

def processdata(file):
    # print(file)
    filename = '../../..' + file.split(".")[-2] + '.pkl'
    # print(filename)
    with open(filename,'rb') as f:
        spectrogram = pickle.load(f)
    return spectrogram

# %%
def getlabel(onehot,labels):
    index = np.argmax(onehot)
    label = labels[index]
    return label

def getonehot(label,labels):
    onehot = np.array([1 if x == label else 0 for x in labels])
    return onehot

# %%
def getdata(df,base_dir):
    df['fullpath'] = base_dir + df['path']
    inputs = df['fullpath'].tolist()
    labels = df['sentence'].tolist()
    x = np.array(inputs)
    y = np.array(labels)
    return x,y

# %%
dftrainEN = pd.read_csv(TRAIN_PATH_EN, sep='\t', header=0)
dftrainEN.sort_values(by='length',ascending=False,inplace=True)
trainxEN,trainyEN, = getdata(dftrainEN.head(NUM_TRAIN_EN), BASE_DIR_EN)

dfvalEN = pd.read_csv(VAL_PATH_EN, sep='\t', header=0)
dfvalEN.sort_values(by='length',ascending=False,inplace=True)
valxEN,valyEN, = getdata(dfvalEN.head(NUM_VAL_EN), BASE_DIR_EN)

dftestEN = pd.read_csv(TEST_PATH_EN, sep='\t', header=0)
dftestEN.sort_values(by='length',ascending=False,inplace=True)
testxEN,testyEN, = getdata(dftestEN.head(NUM_TEST_EN), BASE_DIR_EN)
# Out:
# C:\Users\aning\AppData\Local\Temp/ipykernel_1256/954889505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fullpath'] = base_dir + df['path']

# %%
dftrainES = pd.read_csv(TRAIN_PATH_ES, sep='\t', header=0)
dftrainES.sort_values(by='length',ascending=False,inplace=True)
trainxES,trainyES, = getdata(dftrainES.head(NUM_TRAIN_ES), BASE_DIR_ES)

dfvalES = pd.read_csv(VAL_PATH_ES, sep='\t', header=0)
dfvalES.sort_values(by='length',ascending=False,inplace=True)
valxES,valyES, = getdata(dfvalES.head(NUM_VAL_ES), BASE_DIR_ES)

dftestES = pd.read_csv(TEST_PATH_ES, sep='\t', header=0)
dftestES.sort_values(by='length',ascending=False,inplace=True)
testxES,testyES, = getdata(dftestES.head(NUM_TEST_ES), BASE_DIR_ES)
# Out:
# C:\Users\aning\AppData\Local\Temp/ipykernel_1256/954889505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fullpath'] = base_dir + df['path']

# %%
dftrainFR = pd.read_csv(TRAIN_PATH_FR, sep='\t', header=0)
dftrainFR.sort_values(by='length',ascending=False,inplace=True)
trainxFR,trainyFR, = getdata(dftrainFR.head(NUM_TRAIN_FR), BASE_DIR_FR)

dfvalFR = pd.read_csv(VAL_PATH_FR, sep='\t', header=0)
dfvalFR.sort_values(by='length',ascending=False,inplace=True)
valxFR,valyFR, = getdata(dfvalFR.head(NUM_VAL_FR), BASE_DIR_FR)

dftestFR = pd.read_csv(TEST_PATH_FR, sep='\t', header=0)
dftestFR.sort_values(by='length',ascending=False,inplace=True)
testxFR,testyFR, = getdata(dftestFR.head(NUM_TEST_FR), BASE_DIR_FR)
# Out:
# C:\Users\aning\AppData\Local\Temp/ipykernel_1256/954889505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fullpath'] = base_dir + df['path']

# %%
dftrainDE = pd.read_csv(TRAIN_PATH_DE, sep='\t', header=0)
dftrainDE.sort_values(by='length',ascending=False,inplace=True)
trainxDE,trainyDE, = getdata(dftrainDE.head(NUM_TRAIN_DE), BASE_DIR_DE)

dfvalDE = pd.read_csv(VAL_PATH_DE, sep='\t', header=0)
dfvalDE.sort_values(by='length',ascending=False,inplace=True)
valxDE,valyDE, = getdata(dfvalDE.head(NUM_VAL_DE), BASE_DIR_DE)

dftestDE = pd.read_csv(TEST_PATH_DE, sep='\t', header=0)
dftestDE.sort_values(by='length',ascending=False,inplace=True)
testxDE,testyDE, = getdata(dftestDE.head(NUM_TEST_DE), BASE_DIR_DE)
# Out:
# C:\Users\aning\AppData\Local\Temp/ipykernel_1256/954889505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fullpath'] = base_dir + df['path']

# %%
dftrainCA = pd.read_csv(TRAIN_PATH_CA, sep='\t', header=0)
dftrainCA.sort_values(by='length',ascending=False,inplace=True)
trainxCA,trainyCA, = getdata(dftrainCA.head(NUM_TRAIN_CA), BASE_DIR_CA)

dfvalCA = pd.read_csv(VAL_PATH_CA, sep='\t', header=0)
dfvalCA.sort_values(by='length',ascending=False,inplace=True)
valxCA,valyCA, = getdata(dfvalCA.head(NUM_VAL_CA), BASE_DIR_CA)

dftestCA = pd.read_csv(TEST_PATH_CA, sep='\t', header=0)
dftestCA.sort_values(by='length',ascending=False,inplace=True)
testxCA,testyCA, = getdata(dftestCA.head(NUM_TEST_CA), BASE_DIR_CA)
# Out:
# C:\Users\aning\AppData\Local\Temp/ipykernel_1256/954889505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fullpath'] = base_dir + df['path']

# %%
def maketraingenerator(trainxs, trainys):
    def traingenerator():
        for i in range(len(trainxEN)):
            xs = []
            ys = []

            for trainx,trainy in zip(trainxs,trainys):
                with warnings.catch_warnings():
                    warnings.simplefilter("ignore")
                    xs.append(processdata(trainx[i]))
                ys.append(getonehot(trainy[0][i],trainy[1]))

            xst = tuple(xs)
            yst = tuple(ys)
            yield xst,yst
    return traingenerator


xtypes = tuple([tf.float32]*NUM_LANGUAGES)
ytypes = tuple([tf.int32]*NUM_LANGUAGES)
traingentypes = (xtypes,ytypes)

xshapes = tuple([[FREQ_SIZE,N_MFCC,1] for i in range(NUM_LANGUAGES)])
yshapes = tuple([[15],[14],[15],[15],[14]])
traingenshapes = (xshapes,yshapes)

# %%
def makevalgenerator(trainxs, trainys):
    def traingenerator():
        for i in range(len(valxEN)):
            xs = []
            ys = []

            for trainx,trainy in zip(trainxs,trainys):
                with warnings.catch_warnings():
                    warnings.simplefilter("ignore")
                    xs.append(processdata(trainx[i]))
                ys.append(getonehot(trainy[0][i],trainy[1]))

            xst = tuple(xs)
            yst = tuple(ys)
            yield xst,yst
    return traingenerator

# %%
trainxs = [trainxEN,trainxES,trainxFR,trainxDE,trainxCA]
trainys = [[trainyEN,LABELS_EN],[trainyES,LABELS_ES],[trainyFR,LABELS_FR],[trainyDE,LABELS_DE],[trainyCA,LABELS_CA]]

valxs = [valxEN,valxES,valxFR,valxDE,valxCA]
valys = [[valyEN,LABELS_EN],[valyES,LABELS_ES],[valyFR,LABELS_FR],[valyDE,LABELS_DE],[valyCA,LABELS_CA]]

# %%
def maketestgenerator(testx,testy,labels):
    def testgenerator():
        for i in range(len(testx)):
            x = processdata(testx[i])
            y = getonehot(testy[i],labels)
            yield x,y
    return testgenerator

testgentypes = (tf.float32,tf.int32)
testgenshapes = ([FREQ_SIZE,N_MFCC,1],[15])

# %%
traindataset = tf.data.Dataset.from_generator(maketraingenerator(trainxs,trainys),output_types=traingentypes,output_shapes=traingenshapes)
traindataset = traindataset.shuffle(NUM_TRAIN_EN)
traindataset = traindataset.batch(BATCH_SIZE_TRAIN)
traindataset = traindataset.repeat(-1)
traindataset = traindataset.cache().prefetch(AUTOTUNE)

valdataset = tf.data.Dataset.from_generator(makevalgenerator(valxs,valys),output_types=traingentypes,output_shapes=traingenshapes)
valdataset = valdataset.batch(BATCH_SIZE_VAL)
valdataset = valdataset.cache().prefetch(AUTOTUNE)

testdatasetEN = tf.data.Dataset.from_generator(maketestgenerator(testxEN,testyEN,LABELS_EN),output_types=testgentypes,output_shapes=testgenshapes)
testdatasetEN = testdatasetEN.batch(BATCH_SIZE_TEST)

testdatasetES = tf.data.Dataset.from_generator(maketestgenerator(testxES,testyES,LABELS_ES),output_types=testgentypes,output_shapes=([FREQ_SIZE,N_MFCC,1],[14]))
testdatasetES = testdatasetES.batch(BATCH_SIZE_TEST)

testdatasetFR = tf.data.Dataset.from_generator(maketestgenerator(testxFR,testyFR,LABELS_FR),output_types=testgentypes,output_shapes=testgenshapes)
testdatasetFR = testdatasetFR.batch(BATCH_SIZE_TEST)

testdatasetDE = tf.data.Dataset.from_generator(maketestgenerator(testxDE,testyDE,LABELS_DE),output_types=testgentypes,output_shapes=testgenshapes)
testdatasetDE = testdatasetDE.batch(BATCH_SIZE_TEST)

testdatasetCA = tf.data.Dataset.from_generator(maketestgenerator(testxCA,testyCA,LABELS_CA),output_types=testgentypes,output_shapes=([FREQ_SIZE,N_MFCC,1],[14]))
testdatasetCA = testdatasetCA.batch(BATCH_SIZE_TEST)

# %%
def languagelayers(num_labels,language):
        lang = keras.Sequential([
        layers.Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', activation=activations.relu, name=language+'_Conv2D1'),
        layers.MaxPooling2D(pool_size=(2,2), strides=(2,2), name=language+'_MaxPool2D1'),
        # layers.Conv2D(filters=512, kernel_size=(2,2), strides=(1,1), padding='same', activation=activations.relu, name=language+'_Conv2D2'),
        # layers.MaxPooling2D(pool_size=(2,2), strides=(2,2), name=language+'_MaxPool2D2'),
        layers.Flatten(),
        layers.Dropout(0.2),
        layers.Dense(128, activation=activations.relu, name=language+'_DenseLayer1'),
        layers.Dropout(0.2),
        layers.Dense(128, activation=activations.relu, name=language+'_DenseLayer2'),
        layers.Dropout(0.2),
        layers.Dense(num_labels, activation=activations.softmax, name=language+'_Output')
        ],
        name=language)

        return lang

# %%
inputEN = tf.keras.Input(shape=(FREQ_SIZE,N_MFCC,1),name='EN_Input')
inputES = tf.keras.Input(shape=(FREQ_SIZE,N_MFCC,1),name='ES_Input')
inputFR = tf.keras.Input(shape=(FREQ_SIZE,N_MFCC,1),name='FR_Input')
inputDE = tf.keras.Input(shape=(FREQ_SIZE,N_MFCC,1),name='DE_Input')
inputCA = tf.keras.Input(shape=(FREQ_SIZE,N_MFCC,1),name='CA_Input')

shared = keras.Sequential([
    layers.Conv2D(filters=32, kernel_size=(9,9), strides=(2,2), padding='same', activation=activations.relu, name='Shared_Conv2D1'),
    layers.MaxPooling2D(pool_size=(3,3), strides=(2,2), name='Shared_MaxPool2D1'),
    layers.Conv2D(filters=64, kernel_size=(5,5), strides=(1,1), padding='same', activation=activations.relu, name='Shared_Conv2D2'),
    layers.MaxPooling2D(pool_size=(3,3), strides=(2,2), name='Shared_MaxPool2D2'),
    layers.Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', activation=activations.relu, name='Shared_Conv2D3'),
    layers.MaxPooling2D(pool_size=(3,3), strides=(2,2), name='Shared_MaxPool2D3'),
    # layers.Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', activation=activations.relu, name='Shared_Conv2D4'),
    # layers.MaxPooling2D(pool_size=(2,2), strides=(2,2), name='Shared_MaxPool2D4'),
    ],
    name='Shared_Layers'
)

sharedLayersEN = shared(inputEN)
sharedLayersES = shared(inputES)
sharedLayersFR = shared(inputFR)
sharedLayersDE = shared(inputDE)
sharedLayersCA = shared(inputCA)

layersEN = languagelayers(NUM_LABELS_EN,'EN')(sharedLayersEN)
layersES = languagelayers(NUM_LABELS_ES,'ES')(sharedLayersES)
layersFR = languagelayers(NUM_LABELS_FR,'FR')(sharedLayersFR)
layersDE = languagelayers(NUM_LABELS_DE,'DE')(sharedLayersDE)
layersCA = languagelayers(NUM_LABELS_CA,'CA')(sharedLayersCA)

model = tf.keras.Model(
    inputs=[inputEN,inputES,inputFR,inputDE,inputCA],
    outputs=[layersEN,layersES,layersFR,layersDE,layersCA],
    name='Full_Model'
)


model.summary(expand_nested=True)
tf.keras.utils.plot_model(model, expand_nested=True)
# Out:
# Model: "Full_Model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  EN_Input (InputLayer)          [(None, 188, 100, 1  0           []
#                                 )]
#
#  ES_Input (InputLayer)          [(None, 188, 100, 1  0           []
#                                 )]
#
#  FR_Input (InputLayer)          [(None, 188, 100, 1  0           []
#                                 )]
#
#  DE_Input (InputLayer)          [(None, 188, 100, 1  0           []
#                                 )]
#
#  CA_Input (InputLayer)          [(None, 188, 100, 1  0           []
#                                 )]
#
#  Shared_Layers (Sequential)     (None, 10, 5, 128)   127744      ['EN_Input[0][0]',
#                                                                   'ES_Input[0][0]',
#                                                                   'FR_Input[0][0]',
#                                                                   'DE_Input[0][0]',
#                                                                   'CA_Input[0][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | Shared_Conv2D1 (Conv2D)      (None, 94, 50, 32)   2624        []                               |
# |                                                                                                |
# | Shared_MaxPool2D1 (MaxPooling2  (None, 46, 24, 32)  0         []                               |
# | D)                                                                                             |
# |                                                                                                |
# | Shared_Conv2D2 (Conv2D)      (None, 46, 24, 64)   51264       []                               |
# |                                                                                                |
# | Shared_MaxPool2D2 (MaxPooling2  (None, 22, 11, 64)  0         []                               |
# | D)                                                                                             |
# |                                                                                                |
# | Shared_Conv2D3 (Conv2D)      (None, 22, 11, 128)  73856       []                               |
# |                                                                                                |
# | Shared_MaxPool2D3 (MaxPooling2  (None, 10, 5, 128)  0         []                               |
# | D)                                                                                             |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  EN (Sequential)                (None, 15)           329999      ['Shared_Layers[0][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | EN_Conv2D1 (Conv2D)          (None, 10, 5, 128)   147584      []                               |
# |                                                                                                |
# | EN_MaxPool2D1 (MaxPooling2D)  (None, 5, 2, 128)   0           []                               |
# |                                                                                                |
# | flatten_10 (Flatten)         (None, 1280)         0           []                               |
# |                                                                                                |
# | dropout_30 (Dropout)         (None, 1280)         0           []                               |
# |                                                                                                |
# | EN_DenseLayer1 (Dense)       (None, 128)          163968      []                               |
# |                                                                                                |
# | dropout_31 (Dropout)         (None, 128)          0           []                               |
# |                                                                                                |
# | EN_DenseLayer2 (Dense)       (None, 128)          16512       []                               |
# |                                                                                                |
# | dropout_32 (Dropout)         (None, 128)          0           []                               |
# |                                                                                                |
# | EN_Output (Dense)            (None, 15)           1935        []                               |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  ES (Sequential)                (None, 14)           329870      ['Shared_Layers[1][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | ES_Conv2D1 (Conv2D)          (None, 10, 5, 128)   147584      []                               |
# |                                                                                                |
# | ES_MaxPool2D1 (MaxPooling2D)  (None, 5, 2, 128)   0           []                               |
# |                                                                                                |
# | flatten_11 (Flatten)         (None, 1280)         0           []                               |
# |                                                                                                |
# | dropout_33 (Dropout)         (None, 1280)         0           []                               |
# |                                                                                                |
# | ES_DenseLayer1 (Dense)       (None, 128)          163968      []                               |
# |                                                                                                |
# | dropout_34 (Dropout)         (None, 128)          0           []                               |
# |                                                                                                |
# | ES_DenseLayer2 (Dense)       (None, 128)          16512       []                               |
# |                                                                                                |
# | dropout_35 (Dropout)         (None, 128)          0           []                               |
# |                                                                                                |
# | ES_Output (Dense)            (None, 14)           1806        []                               |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  FR (Sequential)                (None, 15)           329999      ['Shared_Layers[2][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | FR_Conv2D1 (Conv2D)          (None, 10, 5, 128)   147584      []                               |
# |                                                                                                |
# | FR_MaxPool2D1 (MaxPooling2D)  (None, 5, 2, 128)   0           []                               |
# |                                                                                                |
# | flatten_12 (Flatten)         (None, 1280)         0           []                               |
# |                                                                                                |
# | dropout_36 (Dropout)         (None, 1280)         0           []                               |
# |                                                                                                |
# | FR_DenseLayer1 (Dense)       (None, 128)          163968      []                               |
# |                                                                                                |
# | dropout_37 (Dropout)         (None, 128)          0           []                               |
# |                                                                                                |
# | FR_DenseLayer2 (Dense)       (None, 128)          16512       []                               |
# |                                                                                                |
# | dropout_38 (Dropout)         (None, 128)          0           []                               |
# |                                                                                                |
# | FR_Output (Dense)            (None, 15)           1935        []                               |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  DE (Sequential)                (None, 15)           329999      ['Shared_Layers[3][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | DE_Conv2D1 (Conv2D)          (None, 10, 5, 128)   147584      []                               |
# |                                                                                                |
# | DE_MaxPool2D1 (MaxPooling2D)  (None, 5, 2, 128)   0           []                               |
# |                                                                                                |
# | flatten_13 (Flatten)         (None, 1280)         0           []                               |
# |                                                                                                |
# | dropout_39 (Dropout)         (None, 1280)         0           []                               |
# |                                                                                                |
# | DE_DenseLayer1 (Dense)       (None, 128)          163968      []                               |
# |                                                                                                |
# | dropout_40 (Dropout)         (None, 128)          0           []                               |
# |                                                                                                |
# | DE_DenseLayer2 (Dense)       (None, 128)          16512       []                               |
# |                                                                                                |
# | dropout_41 (Dropout)         (None, 128)          0           []                               |
# |                                                                                                |
# | DE_Output (Dense)            (None, 15)           1935        []                               |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  CA (Sequential)                (None, 14)           329870      ['Shared_Layers[4][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | CA_Conv2D1 (Conv2D)          (None, 10, 5, 128)   147584      []                               |
# |                                                                                                |
# | CA_MaxPool2D1 (MaxPooling2D)  (None, 5, 2, 128)   0           []                               |
# |                                                                                                |
# | flatten_14 (Flatten)         (None, 1280)         0           []                               |
# |                                                                                                |
# | dropout_42 (Dropout)         (None, 1280)         0           []                               |
# |                                                                                                |
# | CA_DenseLayer1 (Dense)       (None, 128)          163968      []                               |
# |                                                                                                |
# | dropout_43 (Dropout)         (None, 128)          0           []                               |
# |                                                                                                |
# | CA_DenseLayer2 (Dense)       (None, 128)          16512       []                               |
# |                                                                                                |
# | dropout_44 (Dropout)         (None, 128)          0           []                               |
# |                                                                                                |
# | CA_Output (Dense)            (None, 14)           1806        []                               |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# ==================================================================================================
# Total params: 1,777,481
# Trainable params: 1,777,481
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=[tf.keras.losses.CategoricalCrossentropy(),tf.keras.losses.CategoricalCrossentropy(),tf.keras.losses.CategoricalCrossentropy(),tf.keras.losses.CategoricalCrossentropy(),tf.keras.losses.CategoricalCrossentropy()],
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='Categorical_Accuracy'), tf.keras.metrics.AUC(name='AUC')]
)

# %%
training_callback = callbacks.TensorBoard(log_dir=LOG_DIR + RUN)
reduce_lr_callback = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2,min_lr=1e-5,verbose=1)
earlystopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
# model.predict(testdatasetEN)

# %%
history = model.fit(
    x = traindataset,
    validation_data = valdataset,
    epochs=EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    callbacks=[training_callback,earlystopping_callback,reduce_lr_callback],
    verbose=1
)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 77s 1s/step - loss: 13.1896 - EN_loss: 2.7019 - ES_loss: 2.4103 - FR_loss: 2.7056 - DE_loss: 2.7181 - CA_loss: 2.6536 - EN_Categorical_Accuracy: 0.0756 - EN_AUC: 0.5308 - ES_Categorical_Accuracy: 0.0844 - ES_AUC: 0.5407 - FR_Categorical_Accuracy: 0.0800 - FR_AUC: 0.5254 - DE_Categorical_Accuracy: 0.0711 - DE_AUC: 0.5192 - CA_Categorical_Accuracy: 0.0722 - CA_AUC: 0.5123 - val_loss: 13.0965 - val_EN_loss: 2.6816 - val_ES_loss: 2.4192 - val_FR_loss: 2.6891 - val_DE_loss: 2.6718 - val_CA_loss: 2.6348 - val
# 36/36 [==============================] - 27s 760ms/step - loss: 4.1498 - EN_loss: 0.7678 - ES_loss: 1.5258 - FR_loss: 0.6377 - DE_loss: 0.7030 - CA_loss: 0.5155 - EN_Categorical_Accuracy: 0.7278 - EN_AUC: 0.9802 - ES_Categorical_Accuracy: 0.5778 - ES_AUC: 0.9123 - FR_Categorical_Accuracy: 0.7822 - FR_AUC: 0.9872 - DE_Categorical_Accuracy: 0.7578 - DE_AUC: 0.9837 - CA_Categorical_Accuracy: 0.8156 - CA_AUC: 0.9898 - val_loss: 7.4148 - val_EN_loss: 1.5107 - val_ES_loss: 1.4184 - val_FR_loss: 1.5011 - val_DE_loss: 1.7619 - val_CA_loss: 1.2228 - val_EN_Categorical_Accuracy: 0.4980 - val_EN_AUC: 0.9160 - val_ES_Categorical_Accuracy: 0.4900 - val_ES_AUC: 0.9163 - val_FR_Categorical_Accuracy: 0.5040 - val_FR_AUC: 0.9145 - val_DE_Categorical_Accuracy: 0.4240 - val_DE_AUC: 0.8842 - val_CA_Categorical_Accuracy: 0.5780 - val_CA_AUC: 0.9435 - lr: 1.0000e-05

# %%
modelEN = tf.keras.Model(
    inputs=inputEN,
    outputs=layersEN,
    name='ENModel'
)

modelEN.compile(optimizer = tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='Categorical Accuracy'),tf.keras.metrics.AUC(name='AUC')])

modelEN.evaluate(testdatasetEN)
# Out:
# 250/250 [==============================] - 5s 15ms/step - loss: 1.7282 - Categorical Accuracy: 0.4560 - AUC: 0.8902
# [1.7281594276428223, 0.4560000002384186, 0.8901684284210205]

# %%
modelES = tf.keras.Model(
    inputs=inputES,
    outputs=layersES,
    name='ESModel'
)

modelES.compile(optimizer = tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='Categorical Accuracy'),tf.keras.metrics.AUC(name='AUC')])

modelES.evaluate(testdatasetES)
# Out:
# 250/250 [==============================] - 4s 14ms/step - loss: 1.6723 - Categorical Accuracy: 0.4480 - AUC: 0.8881
# [1.672324538230896, 0.4480000138282776, 0.8880600929260254]

# %%
modelFR = tf.keras.Model(
    inputs=inputFR,
    outputs=layersFR,
    name='FRModel'
)

modelFR.compile(optimizer = tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='Categorical Accuracy'),tf.keras.metrics.AUC(name='AUC')])

modelFR.evaluate(testdatasetFR)
# Out:
# 250/250 [==============================] - 4s 13ms/step - loss: 1.6993 - Categorical Accuracy: 0.4480 - AUC: 0.8894
# [1.6993434429168701, 0.4480000138282776, 0.8894275426864624]

# %%
modelDE = tf.keras.Model(
    inputs=inputDE,
    outputs=layersDE,
    name='DEModel'
)

modelDE.compile(optimizer = tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='Categorical Accuracy'),tf.keras.metrics.AUC(name='AUC')])

modelDE.evaluate(testdatasetDE)
# Out:
# 250/250 [==============================] - 4s 13ms/step - loss: 1.8574 - Categorical Accuracy: 0.4080 - AUC: 0.8686
# [1.8573602437973022, 0.40799999237060547, 0.8686343431472778]

# %%
modelCA = tf.keras.Model(
    inputs=inputCA,
    outputs=layersCA,
    name='CAModel'
)

modelCA.compile(optimizer = tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='Categorical Accuracy'),tf.keras.metrics.AUC(name='AUC')])

modelCA.evaluate(testdatasetCA)
# Out:
# 250/250 [==============================] - 3s 13ms/step - loss: 1.4259 - Categorical Accuracy: 0.5160 - AUC: 0.9206
# [1.4258732795715332, 0.515999972820282, 0.9206239581108093]

# %%
model.save('savedmodels/model5' + RUN)
shared.save('savedmodels/model52-Shared')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) EN_Input, ES_Input, FR_Input, DE_Input, CA_Input with unsupported characters which will be renamed to en_input, es_input, fr_input, de_input, ca_input in the SavedModel.
# INFO:tensorflow:Assets written to: savedmodels/model52\assets
# INFO:tensorflow:Assets written to: savedmodels/model52\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Shared_Conv2D1_input with unsupported characters which will be renamed to shared_conv2d1_input in the SavedModel.
# INFO:tensorflow:Assets written to: savedmodels/model52-Shared\assets
# INFO:tensorflow:Assets written to: savedmodels/model52-Shared\assets

# %%
# modelsave = keras.models.load_model('savedmodels/model22')
#
# model.summary()

# %%
shared.trainable = False

# %%
newSharedLayersEN = shared(inputEN)
newLayersEN = languagelayers(NUM_LABELS_EN,'EN')(newSharedLayersEN)

# %%
modelENRetrain = tf.keras.Model(
    inputs=inputEN,
    outputs=newLayersEN,
    name='ENModelRetrain'
)

# %%
modelENRetrain.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='Categorical Accuracy'),tf.keras.metrics.AUC(name='AUC')]
)

modelENRetrain.summary(expand_nested=True)
tf.keras.utils.plot_model(modelENRetrain, expand_nested=True)
# Out:
# Model: "ENModelRetrain"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  EN_Input (InputLayer)       [(None, 188, 100, 1)]     0
#
#  Shared_Layers (Sequential)  (None, 10, 5, 128)        127744
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | Shared_Conv2D1 (Conv2D)   (None, 94, 50, 32)        2624      |
# |                                                               |
# | Shared_MaxPool2D1 (MaxPooli  (None, 46, 24, 32)     0         |
# | ng2D)                                                         |
# |                                                               |
# | Shared_Conv2D2 (Conv2D)   (None, 46, 24, 64)        51264     |
# |                                                               |
# | Shared_MaxPool2D2 (MaxPooli  (None, 22, 11, 64)     0         |
# | ng2D)                                                         |
# |                                                               |
# | Shared_Conv2D3 (Conv2D)   (None, 22, 11, 128)       73856     |
# |                                                               |
# | Shared_MaxPool2D3 (MaxPooli  (None, 10, 5, 128)     0         |
# | ng2D)                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  EN (Sequential)             (None, 15)                329999
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | EN_Conv2D1 (Conv2D)       (None, 10, 5, 128)        147584    |
# |                                                               |
# | EN_MaxPool2D1 (MaxPooling2D  (None, 5, 2, 128)      0         |
# | )                                                             |
# |                                                               |
# | flatten_15 (Flatten)      (None, 1280)              0         |
# |                                                               |
# | dropout_45 (Dropout)      (None, 1280)              0         |
# |                                                               |
# | EN_DenseLayer1 (Dense)    (None, 128)               163968    |
# |                                                               |
# | dropout_46 (Dropout)      (None, 128)               0         |
# |                                                               |
# | EN_DenseLayer2 (Dense)    (None, 128)               16512     |
# |                                                               |
# | dropout_47 (Dropout)      (None, 128)               0         |
# |                                                               |
# | EN_Output (Dense)         (None, 15)                1935      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 457,743
# Trainable params: 329,999
# Non-trainable params: 127,744
# _________________________________________________________________

# %%
trainxENs = [trainxEN]
trainyENs = [[trainyEN,LABELS_EN]]

valxENs = [valxEN]
valyENs = [[valyEN,LABELS_EN]]

xtypes = tuple([tf.float32]*1)
ytypes = tuple([tf.int32]*1)
traingentypes = (xtypes,ytypes)

xshapes = tuple([[FREQ_SIZE,N_MFCC,1] for i in range(1)])
yshapes = tuple([[15]])
traingenshapes = (xshapes,yshapes)

traindatasetEN = tf.data.Dataset.from_generator(maketraingenerator(trainxENs,trainyENs),output_types=traingentypes,output_shapes=traingenshapes)
traindatasetEN = traindatasetEN.shuffle(NUM_TRAIN_EN)
traindatasetEN = traindatasetEN.batch(BATCH_SIZE_TRAIN)
traindatasetEN = traindatasetEN.repeat(-1)
traindatasetEN = traindatasetEN.cache().prefetch(AUTOTUNE)

valdatasetEN = tf.data.Dataset.from_generator(makevalgenerator(valxENs,valyENs),output_types=traingentypes,output_shapes=traingenshapes)
valdatasetEN = valdatasetEN.batch(BATCH_SIZE_VAL)
valdatasetEN = valdatasetEN.cache().prefetch(AUTOTUNE)

# %%
training_callbackEN = callbacks.TensorBoard(log_dir=LOG_DIR + RUN + '-Retrain-EN')

historyEN = modelENRetrain.fit(
    x = traindatasetEN,
    validation_data = valdatasetEN,
    epochs=EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    callbacks=[training_callbackEN,earlystopping_callback,reduce_lr_callback],
    verbose=1
)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 4s 80ms/step - loss: 2.8057 - Categorical Accuracy: 0.0911 - AUC: 0.5566 - val_loss: 2.6016 - val_Categorical Accuracy: 0.1600 - val_AUC: 0.6410 - lr: 1.0000e-04
# Epoch 2/100
# 36/36 [==============================] - 2s 54ms/step - loss: 2.5864 - Categorical Accuracy: 0.1489 - AUC: 0.6453 - val_loss: 2.4916 - val_Categorical Accuracy: 0.2060 - val_AUC: 0.7062 - lr: 1.0000e-04
# Epoch 3/100
# 36/36 [==============================] - 2s 54ms/step - loss: 2.4898 - Categorical Accuracy: 0.2100 - AUC: 0.6837 - val_loss: 2.3677 - val_Categorical Accuracy: 0.2300 - val_AUC: 0.7518 - lr: 1.0000e-04
# Epoch 4/100
# 36/36 [==============================] - 2s 54ms/step - loss: 2.3128 - Categorical Accuracy: 0.2367 - AUC: 0.7524 - val_loss: 2.2451 - val_Categorical Accuracy: 0.2860 - val_AUC: 0.7841 - lr: 1.0000e-04
# Epoch 5/100
# 36/36 [==============================] - 2s 54ms/step - loss: 2.2304 - Categorical Accuracy: 0.2611 - AUC: 0.7782 - val_loss: 2.1511 - val_Categorical Accuracy: 0.3640 - val_AUC: 0.8137 - lr: 1.0000e-04
# Epoch 6/100
# 36/36 [==============================] - 2s 53ms/step - loss: 2.0958 - Categorical Accuracy: 0.3167 - AUC: 0.8138 - val_loss: 2.0542 - val_Categorical Accuracy: 0.3420 - val_AUC: 0.8305 - lr: 1.0000e-04
# Epoch 7/100
# 36/36 [==============================] - 2s 55ms/step - loss: 1.9580 - Categorical Accuracy: 0.3511 - AUC: 0.8439 - val_loss: 1.9361 - val_Categorical Accuracy: 0.3680 - val_AUC: 0.8613 - lr: 1.0000e-04
# Epoch 8/100
# 36/36 [==============================] - 2s 55ms/step - loss: 1.8984 - Categorical Accuracy: 0.3600 - AUC: 0.8562 - val_loss: 1.8659 - val_Categorical Accuracy: 0.3920 - val_AUC: 0.8687 - lr: 1.0000e-04
# Epoch 9/100
# 36/36 [==============================] - 2s 58ms/step - loss: 1.7610 - Categorical Accuracy: 0.4244 - AUC: 0.8809 - val_loss: 1.7958 - val_Categorical Accuracy: 0.3880 - val_AUC: 0.8829 - lr: 1.0000e-04
# Epoch 10/100
# 36/36 [==============================] - 2s 55ms/step - loss: 1
100
# 36/36 [==============================] - 2s 53ms/step - loss: 0.8778 - Categorical Accuracy: 0.6989 - AUC: 0.9741 - val_loss: 1.4237 - val_Categorical Accuracy: 0.4900 - val_AUC: 0.9244 - lr: 1.0000e-05
# Epoch 48/100
# 36/36 [==============================] - 2s 59ms/step - loss: 0.8590 - Categorical Accuracy: 0.7200 - AUC: 0.9754 - val_loss: 1.4234 - val_Categorical Accuracy: 0.4900 - val_AUC: 0.9244 - lr: 1.0000e-05

# %%
modelENRetrain.evaluate(testdatasetEN)
# Out:
# 250/250 [==============================] - 2s 7ms/step - loss: 1.6371 - Categorical Accuracy: 0.4280 - AUC: 0.8946
# [1.6371275186538696, 0.42800000309944153, 0.894584596157074]

# %%
# modelENRetrain.save('savedmodels/model-EN-Retrain')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) EN_Input with unsupported characters which will be renamed to en_input in the SavedModel.
# INFO:tensorflow:Assets written to: savedmodels/model-EN-Retrain\assets
# INFO:tensorflow:Assets written to: savedmodels/model-EN-Retrain\assets

# %%
newSharedLayersES = shared(inputES)
newLayersES = languagelayers(NUM_LABELS_ES,'ES')(newSharedLayersES)

# %%
modelESRetrain = tf.keras.Model(
    inputs=inputES,
    outputs=newLayersES,
    name='ESModelRetrain'
)

# %%
modelESRetrain.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='Categorical Accuracy'),tf.keras.metrics.AUC(name='AUC')]
)

modelESRetrain.summary(expand_nested=True)
tf.keras.utils.plot_model(modelESRetrain, expand_nested=True)
# Out:
# Model: "ESModelRetrain"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  ES_Input (InputLayer)       [(None, 188, 100, 1)]     0
#
#  Shared_Layers (Sequential)  (None, 10, 5, 128)        127744
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | Shared_Conv2D1 (Conv2D)   (None, 94, 50, 32)        2624      |
# |                                                               |
# | Shared_MaxPool2D1 (MaxPooli  (None, 46, 24, 32)     0         |
# | ng2D)                                                         |
# |                                                               |
# | Shared_Conv2D2 (Conv2D)   (None, 46, 24, 64)        51264     |
# |                                                               |
# | Shared_MaxPool2D2 (MaxPooli  (None, 22, 11, 64)     0         |
# | ng2D)                                                         |
# |                                                               |
# | Shared_Conv2D3 (Conv2D)   (None, 22, 11, 128)       73856     |
# |                                                               |
# | Shared_MaxPool2D3 (MaxPooli  (None, 10, 5, 128)     0         |
# | ng2D)                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  ES (Sequential)             (None, 14)                329870
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | ES_Conv2D1 (Conv2D)       (None, 10, 5, 128)        147584    |
# |                                                               |
# | ES_MaxPool2D1 (MaxPooling2D  (None, 5, 2, 128)      0         |
# | )                                                             |
# |                                                               |
# | flatten_16 (Flatten)      (None, 1280)              0         |
# |                                                               |
# | dropout_48 (Dropout)      (None, 1280)              0         |
# |                                                               |
# | ES_DenseLayer1 (Dense)    (None, 128)               163968    |
# |                                                               |
# | dropout_49 (Dropout)      (None, 128)               0         |
# |                                                               |
# | ES_DenseLayer2 (Dense)    (None, 128)               16512     |
# |                                                               |
# | dropout_50 (Dropout)      (None, 128)               0         |
# |                                                               |
# | ES_Output (Dense)         (None, 14)                1806      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 457,614
# Trainable params: 329,870
# Non-trainable params: 127,744
# _________________________________________________________________

# %%
trainxESs = [trainxES]
trainyESs = [[trainyES,LABELS_ES]]

valxESs = [valxES]
valyESs = [[valyES,LABELS_ES]]

xtypes = tuple([tf.float32]*1)
ytypes = tuple([tf.int32]*1)
traingentypes = (xtypes,ytypes)

xshapes = tuple([[FREQ_SIZE,N_MFCC,1] for i in range(1)])
yshapes = tuple([[14]])
traingenshapes = (xshapes,yshapes)

traindatasetES = tf.data.Dataset.from_generator(maketraingenerator(trainxESs,trainyESs),output_types=traingentypes,output_shapes=traingenshapes)
traindatasetES = traindatasetES.shuffle(NUM_TRAIN_ES)
traindatasetES = traindatasetES.batch(BATCH_SIZE_TRAIN)
traindatasetES = traindatasetES.repeat(-1)
traindatasetES = traindatasetES.cache().prefetch(AUTOTUNE)

valdatasetES = tf.data.Dataset.from_generator(makevalgenerator(valxESs,valyESs),output_types=traingentypes,output_shapes=traingenshapes)
valdatasetES = valdatasetES.batch(BATCH_SIZE_VAL)
valdatasetES = valdatasetES.cache().prefetch(AUTOTUNE)

# %%
training_callbackES = callbacks.TensorBoard(log_dir=LOG_DIR + RUN + '-Retrain-ES')

historyES = modelESRetrain.fit(
    x = traindatasetES,
    validation_data = valdatasetES,
    epochs=EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    callbacks=[training_callbackES,earlystopping_callback,reduce_lr_callback],
    verbose=1
)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 4s 79ms/step - loss: 2.6063 - Categorical Accuracy: 0.0667 - AUC: 0.5267 - val_loss: 2.4024 - val_Categorical Accuracy: 0.0700 - val_AUC: 0.5994 - lr: 1.0000e-04
# Epoch 2/100
# 36/36 [==============================] - 2s 53ms/step - loss: 2.3964 - Categorical Accuracy: 0.1022 - AUC: 0.5864 - val_loss: 2.3496 - val_Categorical Accuracy: 0.1220 - val_AUC: 0.6641 - lr: 1.0000e-04
# Epoch 3/100
# 36/36 [==============================] - 2s 56ms/step - loss: 2.3114 - Categorical Accuracy: 0.1333 - AUC: 0.6502 - val_loss: 2.3030 - val_Categorical Accuracy: 0.1420 - val_AUC: 0.6961 - lr: 1.0000e-04
# Epoch 4/100
# 36/36 [==============================] - 2s 54ms/step - loss: 2.2215 - Categorical Accuracy: 0.1722 - AUC: 0.7022 - val_loss: 2.2194 - val_Categorical Accuracy: 0.1780 - val_AUC: 0.7473 - lr: 1.0000e-04
# Epoch 5/100
# 36/36 [==============================] - 2s 58ms/step - loss: 2.1260 - Categorical Accuracy: 0.2167 - AUC: 0.7447 - val_loss: 2.1282 - val_Categorical Accuracy: 0.2060 - val_AUC: 0.7847 - lr: 1.0000e-04
# Epoch 6/100
# 36/36 [==============================] - 2s 55ms/step - loss: 1
100
# 36/36 [==============================] - 2s 57ms/step - loss: 0.9503 - Categorical Accuracy: 0.5933 - AUC: 0.9579 - val_loss: 1.2848 - val_Categorical Accuracy: 0.4980 - val_AUC: 0.9220 - lr: 1.0000e-04
# Epoch 25/100
# 36/36 [==============================] - 2s 55ms/step - loss: 0.9212 - Categorical Accuracy: 0.6044 - AUC: 0.9600 - val_loss: 1.2788 - val_Categorical Accuracy: 0.4740 - val_AUC: 0.9209 - lr: 1.0000e-04
# Epoch 26/100
# 36/36 [==============================] - 2s 53ms/step - loss: 0.9227 - Categorical Accuracy: 0.5756 - AUC: 0.9597 - val_loss: 1.2905 - val_Categorical Accuracy: 0.4740 - val_AUC: 0.9178 - lr: 1.0000e-04
# Epoch 27/100
# 36/36 [==============================] - 2s 53ms/step - loss: 0.8993 - Categorical Accuracy: 0.6067 - AUC: 0.9594 - val_loss: 1.2513 - val_Categorical Accuracy: 0.4820 - val_AUC: 0.9241 - lr: 1.0000e-04
# Epoch 28/100
# 36/36 [==============================] - 2s 54ms/step - loss: 0.8904 - Categorical Accuracy: 0.6233 - AUC: 0.9596 - val_loss: 1.2438 - val_Categorical Accuracy: 0.4940 - val_AUC: 0.9248 - lr: 1.0000e-04
# Epoch 29/100
# 36/36 [==============================] - 2s 53ms/step - loss: 0.8443 - Categorical Accuracy: 0.6100 - AUC: 0.9649 - val_loss: 1.2178 - val_Categorical Accuracy: 0.4980 - val_AUC: 0.9282 - lr: 1.0000e-04
# Epoch 30/100
# 36/36 [==============================] - 2s 54ms/step - loss: 0.8261 - Categorical Accuracy: 0.6556 - AUC: 0.9658 - val_loss: 1.2881 - val_Categorical Accuracy: 0.4600 - val_AUC: 0.9216 - lr: 1.0000e-04
# Epoch 31/100
# 36/36 [==============================] - ETA: 0s - loss: 0.9083 - Categorical Accuracy: 0.6056 - AUC: 0.9568
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 36/36 [==============================] - 2s 55ms/step - loss: 0.9083 - Categorical Accuracy: 0.6056 - AUC: 0.9568 - val_loss: 1.2260 - val_Categorical Accuracy: 0.5040 - val_AUC: 0.9258 - lr: 1.0000e-04
# Epoch 32/100
# 36/36 [==============================] - 2s 54ms/step - loss: 0.8427 - Categorical Accuracy: 0.6256 - AUC: 0.9629 - val_loss: 1.2209 - val_Categorical Accuracy: 0.5040 - val_AUC: 0.9267 - lr: 2.0000e-05
# Epoch 33/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.8709 - Categorical Accuracy: 0.6194 - AUC: 0.9607
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1e-05.
# 36/36 [==============================] - 2s 54ms/step - loss: 0.8670 - Categorical Accuracy: 0.6222 - AUC: 0.9610 - val_loss: 1.2407 - val_Categorical Accuracy: 0.4980 - val_AUC: 0.9256 - lr: 2.0000e-05
# Epoch 34/100
# 36/36 [==============================] - 2s 54ms/step - loss: 0.8775 - Categorical Accuracy: 0.6278 - AUC: 0.9580 - val_loss: 1.2184 - val_Categorical Accuracy: 0.5120 - val_AUC: 0.9276 - lr: 1.0000e-05

# %%
modelESRetrain.evaluate(testdatasetES)
# Out:
# 250/250 [==============================] - 2s 7ms/step - loss: 1.3086 - Categorical Accuracy: 0.5080 - AUC: 0.9218
# [1.3086223602294922, 0.5080000162124634, 0.9218090176582336]

# %%
# modelESRetrain.save('savedmodels/model-ES-Retrain')

# %%
newSharedLayersFR = shared(inputFR)
newLayersFR = languagelayers(NUM_LABELS_FR,'FR')(newSharedLayersFR)

# %%
modelFRRetrain = tf.keras.Model(
    inputs=inputFR,
    outputs=newLayersFR,
    name='FRModelRetrain'
)

# %%
modelFRRetrain.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='Categorical Accuracy'),tf.keras.metrics.AUC(name='AUC')]
)

modelFRRetrain.summary(expand_nested=True)
tf.keras.utils.plot_model(modelFRRetrain, expand_nested=True)
# Out:
# Model: "FRModelRetrain"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  FR_Input (InputLayer)       [(None, 188, 100, 1)]     0
#
#  Shared_Layers (Sequential)  (None, 10, 5, 128)        127744
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | Shared_Conv2D1 (Conv2D)   (None, 94, 50, 32)        2624      |
# |                                                               |
# | Shared_MaxPool2D1 (MaxPooli  (None, 46, 24, 32)     0         |
# | ng2D)                                                         |
# |                                                               |
# | Shared_Conv2D2 (Conv2D)   (None, 46, 24, 64)        51264     |
# |                                                               |
# | Shared_MaxPool2D2 (MaxPooli  (None, 22, 11, 64)     0         |
# | ng2D)                                                         |
# |                                                               |
# | Shared_Conv2D3 (Conv2D)   (None, 22, 11, 128)       73856     |
# |                                                               |
# | Shared_MaxPool2D3 (MaxPooli  (None, 10, 5, 128)     0         |
# | ng2D)                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  FR (Sequential)             (None, 15)                329999
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | FR_Conv2D1 (Conv2D)       (None, 10, 5, 128)        147584    |
# |                                                               |
# | FR_MaxPool2D1 (MaxPooling2D  (None, 5, 2, 128)      0         |
# | )                                                             |
# |                                                               |
# | flatten_17 (Flatten)      (None, 1280)              0         |
# |                                                               |
# | dropout_51 (Dropout)      (None, 1280)              0         |
# |                                                               |
# | FR_DenseLayer1 (Dense)    (None, 128)               163968    |
# |                                                               |
# | dropout_52 (Dropout)      (None, 128)               0         |
# |                                                               |
# | FR_DenseLayer2 (Dense)    (None, 128)               16512     |
# |                                                               |
# | dropout_53 (Dropout)      (None, 128)               0         |
# |                                                               |
# | FR_Output (Dense)         (None, 15)                1935      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 457,743
# Trainable params: 329,999
# Non-trainable params: 127,744
# _________________________________________________________________

# %%
trainxFRs = [trainxFR]
trainyFRs = [[trainyFR,LABELS_FR]]

valxFRs = [valxFR]
valyFRs = [[valyFR,LABELS_FR]]

xtypes = tuple([tf.float32]*1)
ytypes = tuple([tf.int32]*1)
traingentypes = (xtypes,ytypes)

xshapes = tuple([[FREQ_SIZE,N_MFCC,1] for i in range(1)])
yshapes = tuple([[15]])
traingenshapes = (xshapes,yshapes)

traindatasetFR = tf.data.Dataset.from_generator(maketraingenerator(trainxFRs,trainyFRs),output_types=traingentypes,output_shapes=traingenshapes)
traindatasetFR = traindatasetFR.shuffle(NUM_TRAIN_ES)
traindatasetFR = traindatasetFR.batch(BATCH_SIZE_TRAIN)
traindatasetFR = traindatasetFR.repeat(-1)
traindatasetFR = traindatasetFR.cache().prefetch(AUTOTUNE)

valdatasetFR = tf.data.Dataset.from_generator(makevalgenerator(valxFRs,valyFRs),output_types=traingentypes,output_shapes=traingenshapes)
valdatasetFR = valdatasetFR.batch(BATCH_SIZE_VAL)
valdatasetFR = valdatasetFR.cache().prefetch(AUTOTUNE)

# %%
training_callbackFR = callbacks.TensorBoard(log_dir=LOG_DIR + RUN + '-Retrain-FR')

historyFR = modelFRRetrain.fit(
    x = traindatasetFR,
    validation_data = valdatasetFR,
    epochs=EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    callbacks=[training_callbackFR,earlystopping_callback,reduce_lr_callback],
    verbose=1
)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 4s 78ms/step - loss: 2.8741 - Categorical Accuracy: 0.0722 - AUC: 0.5340 - val_loss: 2.6032 - val_Categorical Accuracy: 0.1240 - val_AUC: 0.6351 - lr: 1.0000e-04
# Epoch 2/100
# 36/36 [==============================] - 2s 54ms/step - loss: 2.5907 - Categorical Accuracy: 0.1333 - AUC: 0.6396 - val_loss: 2.4807 - val_Categorical Accuracy: 0.2220 - val_AUC: 0.7221 - lr: 1.0000e-04
# Epoch 3/100
# 36/36 [==============================] - 2s 53ms/step - loss: 2.4344 - Categorical Accuracy: 0.1967 - AUC: 0.7158 - val_loss: 2.3325 - val_Categorical Accuracy: 0.2760 - val_AUC: 0.7913 - lr: 1.0000e-04
# Epoch 4/100
# 36/36 [==============================] - 2s 53ms/step - loss: 2.2886 - Categorical Accuracy: 0.2322 - AUC: 0.7716 - val_loss: 2.2163 - val_Categorical Accuracy: 0.2880 - val_AUC: 0.8152 - lr: 1.0000e-04
# Epoch 5/100
# 36/36 [==============================] - 2s 54ms/step - loss: 2.1343 - Categorical Accuracy: 0.2722 - AUC: 0.8131 - val_loss: 2.0940 - val_Categorical Accuracy: 0.2960 - val_AUC: 0.8402 - lr: 1.0000e-04
# Epoch 6/100
# 36/36 [==============================] - 2s 55ms/step - loss: 2.0141 - Categorical Accuracy: 0.3133 - AUC: 0.8407 - val_loss: 1.9876 - val_Categorical Accuracy: 0.3300 - val_AUC: 0.8618 - lr: 1.0000e-04
# Epoch 7/100
# 36/36 [==============================] - 2s 59ms/step - loss: 1.8954 - Categorical Accuracy: 0.3389 - AUC: 0.8632 - val_loss: 1.9222 - val_Categorical Accuracy: 0.3360 - val_AUC: 0.8670 - lr: 1.0000e-04
# Epoch 8/100
# 36/36 [==============================] - 2s 58ms/step - loss: 1.7968 - Categorical Accuracy: 0.3578 - AUC: 0.8785 - val_loss: 1.8258 - val_Categorical Accuracy: 0.3640 - val_AUC: 0.8836 - lr: 1.0000e-04
# Epoch 9/100
# 36/36 [==============================] - 2s 59ms/step - loss: 1.7075 - Categorical Accuracy: 0.4067 - AUC: 0.8935 - val_loss: 1.7847 - val_Categorical Accuracy: 0.4240 - val_AUC: 0.8862 - lr: 1.0000e-04
# Epoch 10/100
# 36/36 [==============================] - 2s 59ms/step - loss: 1.6628 - Categorical Accuracy: 0.4311 - AUC: 0.8974 - val_loss: 1.7076 - val_Categorical Accuracy: 0.4540 - val_AUC: 0.8955 - lr: 1.0000e-04
# Epoch 11/100
# 36/36 [==============================] - 2s 58ms/step - loss: 1.5658 - Categorical Accuracy: 0.4489 - AUC: 0.9131 - val_loss: 1.6470 - val_Categorical Accuracy: 0.4260 - val_AUC: 0.9040 - lr: 1.0000e-04
# Epoch 12/100
# 36/36 [==============================] - 2s 60ms/step - loss: 1
100
# 36/36 [==============================] - 2s 59ms/step - loss: 0.8306 - Categorical Accuracy: 0.7222 - AUC: 0.9764 - val_loss: 1.3436 - val_Categorical Accuracy: 0.5220 - val_AUC: 0.9322 - lr: 1.0000e-04
# Epoch 30/100
# 36/36 [==============================] - ETA: 0s - loss: 0.7806 - Categorical Accuracy: 0.7444 - AUC: 0.9804
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 36/36 [==============================] - 2s 60ms/step - loss: 0.7806 - Categorical Accuracy: 0.7444 - AUC: 0.9804 - val_loss: 1.3283 - val_Categorical Accuracy: 0.5380 - val_AUC: 0.9327 - lr: 1.0000e-04
# Epoch 31/100
# 36/36 [==============================] - 2s 59ms/step - loss: 0.7226 - Categorical Accuracy: 0.7578 - AUC: 0.9829 - val_loss: 1.3062 - val_Categorical Accuracy: 0.5460 - val_AUC: 0.9358 - lr: 2.0000e-05
# Epoch 32/100
# 36/36 [==============================] - 2s 60ms/step - loss: 0.6910 - Categorical Accuracy: 0.7567 - AUC: 0.9854 - val_loss: 1.2988 - val_Categorical Accuracy: 0.5600 - val_AUC: 0.9360 - lr: 2.0000e-05
# Epoch 33/100
# 36/36 [==============================] - 2s 60ms/step - loss: 0.6849 - Categorical Accuracy: 0.7600 - AUC: 0.9854 - val_loss: 1.2994 - val_Categorical Accuracy: 0.5420 - val_AUC: 0.9367 - lr: 2.0000e-05
# Epoch 34/100
# 36/36 [==============================] - 2s 59ms/step - loss: 0.7170 - Categorical Accuracy: 0.7656 - AUC: 0.9835 - val_loss: 1.2961 - val_Categorical Accuracy: 0.5480 - val_AUC: 0.9376 - lr: 2.0000e-05
# Epoch 35/100
# 36/36 [==============================] - 2s 59ms/step - loss: 0.6672 - Categorical Accuracy: 0.7844 - AUC: 0.9865 - val_loss: 1.2964 - val_Categorical Accuracy: 0.5520 - val_AUC: 0.9356 - lr: 2.0000e-05
# Epoch 36/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6718 - Categorical Accuracy: 0.7756 - AUC: 0.9856
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1e-05.
# 36/36 [==============================] - 2s 62ms/step - loss: 0.6718 - Categorical Accuracy: 0.7756 - AUC: 0.9856 - val_loss: 1.2979 - val_Categorical Accuracy: 0.5480 - val_AUC: 0.9364 - lr: 2.0000e-05
# Epoch 37/100
# 36/36 [==============================] - 2s 60ms/step - loss: 0.6668 - Categorical Accuracy: 0.7744 - AUC: 0.9857 - val_loss: 1.2984 - val_Categorical Accuracy: 0.5440 - val_AUC: 0.9362 - lr: 1.0000e-05
# Epoch 38/100
# 36/36 [==============================] - 2s 61ms/step - loss: 0.6449 - Categorical Accuracy: 0.8011 - AUC: 0.9869 - val_loss: 1.2985 - val_Categorical Accuracy: 0.5580 - val_AUC: 0.9358 - lr: 1.0000e-05
# Epoch 39/100
# 36/36 [==============================] - 2s 60ms/step - loss: 0.6509 - Categorical Accuracy: 0.8000 - AUC: 0.9868 - val_loss: 1.2984 - val_Categorical Accuracy: 0.5440 - val_AUC: 0.9366 - lr: 1.0000e-05

# %%
modelFRRetrain.evaluate(testdatasetFR)
# Out:
# 250/250 [==============================] - 2s 7ms/step - loss: 1.4365 - Categorical Accuracy: 0.4880 - AUC: 0.9229
# [1.4365181922912598, 0.4880000054836273, 0.9229040741920471]

# %%
# modelFRRetrain.save('savedmodels/model-FR-Retrain')

# %%
newSharedLayersDE = shared(inputDE)
newLayersDE = languagelayers(NUM_LABELS_DE,'DE')(newSharedLayersDE)

# %%
modelDERetrain = tf.keras.Model(
    inputs=inputDE,
    outputs=newLayersDE,
    name='DEModelRetrain'
)

# %%
modelDERetrain.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='Categorical Accuracy'),tf.keras.metrics.AUC(name='AUC')]
)

modelDERetrain.summary(expand_nested=True)
tf.keras.utils.plot_model(modelDERetrain, expand_nested=True)
# Out:
# Model: "DEModelRetrain"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  DE_Input (InputLayer)       [(None, 188, 100, 1)]     0
#
#  Shared_Layers (Sequential)  (None, 10, 5, 128)        127744
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | Shared_Conv2D1 (Conv2D)   (None, 94, 50, 32)        2624      |
# |                                                               |
# | Shared_MaxPool2D1 (MaxPooli  (None, 46, 24, 32)     0         |
# | ng2D)                                                         |
# |                                                               |
# | Shared_Conv2D2 (Conv2D)   (None, 46, 24, 64)        51264     |
# |                                                               |
# | Shared_MaxPool2D2 (MaxPooli  (None, 22, 11, 64)     0         |
# | ng2D)                                                         |
# |                                                               |
# | Shared_Conv2D3 (Conv2D)   (None, 22, 11, 128)       73856     |
# |                                                               |
# | Shared_MaxPool2D3 (MaxPooli  (None, 10, 5, 128)     0         |
# | ng2D)                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  DE (Sequential)             (None, 15)                329999
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | DE_Conv2D1 (Conv2D)       (None, 10, 5, 128)        147584    |
# |                                                               |
# | DE_MaxPool2D1 (MaxPooling2D  (None, 5, 2, 128)      0         |
# | )                                                             |
# |                                                               |
# | flatten_18 (Flatten)      (None, 1280)              0         |
# |                                                               |
# | dropout_54 (Dropout)      (None, 1280)              0         |
# |                                                               |
# | DE_DenseLayer1 (Dense)    (None, 128)               163968    |
# |                                                               |
# | dropout_55 (Dropout)      (None, 128)               0         |
# |                                                               |
# | DE_DenseLayer2 (Dense)    (None, 128)               16512     |
# |                                                               |
# | dropout_56 (Dropout)      (None, 128)               0         |
# |                                                               |
# | DE_Output (Dense)         (None, 15)                1935      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 457,743
# Trainable params: 329,999
# Non-trainable params: 127,744
# _________________________________________________________________

# %%
trainxDEs = [trainxDE]
trainyDEs = [[trainyDE,LABELS_DE]]

valxDEs = [valxDE]
valyDEs = [[valyDE,LABELS_DE]]

xtypes = tuple([tf.float32]*1)
ytypes = tuple([tf.int32]*1)
traingentypes = (xtypes,ytypes)

xshapes = tuple([[FREQ_SIZE,N_MFCC,1] for i in range(1)])
yshapes = tuple([[15]])
traingenshapes = (xshapes,yshapes)

traindatasetDE = tf.data.Dataset.from_generator(maketraingenerator(trainxDEs,trainyDEs),output_types=traingentypes,output_shapes=traingenshapes)
traindatasetDE = traindatasetDE.shuffle(NUM_TRAIN_DE)
traindatasetDE = traindatasetDE.batch(BATCH_SIZE_TRAIN)
traindatasetDE = traindatasetDE.repeat(-1)
traindatasetDE = traindatasetDE.cache().prefetch(AUTOTUNE)

valdatasetDE = tf.data.Dataset.from_generator(makevalgenerator(valxDEs,valyDEs),output_types=traingentypes,output_shapes=traingenshapes)
valdatasetDE = valdatasetDE.batch(BATCH_SIZE_VAL)
valdatasetDE = valdatasetDE.cache().prefetch(AUTOTUNE)

# %%
training_callbackDE = callbacks.TensorBoard(log_dir=LOG_DIR + RUN + '-Retrain-DE')

historyDE = modelDERetrain.fit(
    x = traindatasetDE,
    validation_data = valdatasetDE,
    epochs=EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    callbacks=[training_callbackDE,earlystopping_callback,reduce_lr_callback],
    verbose=1
)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 4s 81ms/step - loss: 2.8768 - Categorical Accuracy: 0.0644 - AUC: 0.5417 - val_loss: 2.6375 - val_Categorical Accuracy: 0.0880 - val_AUC: 0.6080 - lr: 1.0000e-04
# Epoch 2/100
# 36/36 [==============================] - 2s 56ms/step - loss: 2.6521 - Categorical Accuracy: 0.1322 - AUC: 0.6092 - val_loss: 2.5896 - val_Categorical Accuracy: 0.1440 - val_AUC: 0.6589 - lr: 1.0000e-04
# Epoch 3/100
# 36/36 [==============================] - 2s 56ms/step - loss: 2.5489 - Categorical Accuracy: 0.1567 - AUC: 0.6661 - val_loss: 2.5133 - val_Categorical Accuracy: 0.2000 - val_AUC: 0.7213 - lr: 1.0000e-04
# Epoch 4/100
# 36/36 [==============================] - 2s 57ms/step - loss: 2.4634 - Categorical Accuracy: 0.1844 - AUC: 0.7127 - val_loss: 2.4575 - val_Categorical Accuracy: 0.2320 - val_AUC: 0.7366 - lr: 1.0000e-04
# Epoch 5/100
# 36/36 [==============================] - 2s 57ms/step - loss: 2.3469 - Categorical Accuracy: 0.2422 - AUC: 0.7545 - val_loss: 2.3719 - val_Categorical Accuracy: 0.2500 - val_AUC: 0.7603 - lr: 1.0000e-04
# Epoch 6/100
# 36/36 [==============================] - 2s 57ms/step - loss: 2.2454 - Categorical Accuracy: 0.2678 - AUC: 0.7810 - val_loss: 2.2981 - val_Categorical Accuracy: 0.2780 - val_AUC: 0.7812 - lr: 1.0000e-04
# Epoch 7/100
# 36/36 [==============================] - 2s 58ms/step - loss: 2.1384 - Categorical Accuracy: 0.3000 - AUC: 0.8102 - val_loss: 2.2239 - val_Categorical Accuracy: 0.2660 - val_AUC: 0.8006 - lr: 1.0000e-04
# Epoch 8/100
# 36/36 [==============================] - 2s 58ms/step - loss: 2.0520 - Categorical Accuracy: 0.3233 - AUC: 0.8292 - val_loss: 2.1664 - val_Categorical Accuracy: 0.2600 - val_AUC: 0.8112 - lr: 1.0000e-04
# Epoch 9/100
# 36/36 [==============================] - 2s 58ms/step - loss: 1.9212 - Categorical Accuracy: 0.3444 - AUC: 0.8581 - val_loss: 2.0859 - val_Categorical Accuracy: 0.2980 - val_AUC: 0.8265 - lr: 1.0000e-04
# Epoch 10/100
# 36/36 [==============================] - 2s 58ms/step - loss: 1.8400 - Categorical Accuracy: 0.3744 - AUC: 0.8722 - val_loss: 2.0278 - val_Categorical Accuracy: 0.3120 - val_AUC: 0.8405 - lr: 1.0000e-04
# Epoch 11/100
# 36/36 [==============================] - 2s 59ms/step - loss: 1.8197 - Categorical Accuracy: 0.3900 - AUC: 0.8737 - val_loss: 2.0163 - val_Categorical Accuracy: 0.3260 - val_AUC: 0.8396 - lr: 1.0000e-04
# Epoch 12/100
# 36/36 [==============================] - 2s 59ms/step - loss: 1.7253 - Categorical Accuracy: 0.4233 - AUC: 0.8896 - val_loss: 1.9595 - val_Categorical Accuracy: 0.3240 - val_AUC: 0.8483 - lr: 1.0000e-04
# Epoch 13/100
# 36/36 [==============================] - 2s 58ms/step - loss: 1
100
# 36/36 [==============================] - 2s 59ms/step - loss: 0.7385 - Categorical Accuracy: 0.7644 - AUC: 0.9828 - val_loss: 1.5897 - val_Categorical Accuracy: 0.4460 - val_AUC: 0.9040 - lr: 1.0000e-05
# Epoch 43/100
# 36/36 [==============================] - 2s 61ms/step - loss: 0.7237 - Categorical Accuracy: 0.7678 - AUC: 0.9834 - val_loss: 1.5913 - val_Categorical Accuracy: 0.4480 - val_AUC: 0.9040 - lr: 1.0000e-05
# Epoch 44/100
# 36/36 [==============================] - 2s 59ms/step - loss: 0.7295 - Categorical Accuracy: 0.7589 - AUC: 0.9835 - val_loss: 1.5861 - val_Categorical Accuracy: 0.4500 - val_AUC: 0.9032 - lr: 1.0000e-05

# %%
modelDERetrain.evaluate(testdatasetDE)
# Out:
# 250/250 [==============================] - 4s 16ms/step - loss: 1.7601 - Categorical Accuracy: 0.4480 - AUC: 0.8774
# [1.7600563764572144, 0.4480000138282776, 0.8774240016937256]

# %%
# modelDERetrain.save('savedmodels/model-DE-Retrain')

# %%
newSharedLayersCA = shared(inputCA)
newLayersCA = languagelayers(NUM_LABELS_CA,'CA')(newSharedLayersCA)

# %%
modelCARetrain = tf.keras.Model(
    inputs=inputCA,
    outputs=newLayersCA,
    name='CAModelRetrain'
)

# %%
modelCARetrain.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='Categorical Accuracy'),tf.keras.metrics.AUC(name='AUC')]
)

modelCARetrain.summary(expand_nested=True)
tf.keras.utils.plot_model(modelCARetrain, expand_nested=True)
# Out:
# Model: "CAModelRetrain"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  CA_Input (InputLayer)       [(None, 188, 100, 1)]     0
#
#  Shared_Layers (Sequential)  (None, 10, 5, 128)        127744
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | Shared_Conv2D1 (Conv2D)   (None, 94, 50, 32)        2624      |
# |                                                               |
# | Shared_MaxPool2D1 (MaxPooli  (None, 46, 24, 32)     0         |
# | ng2D)                                                         |
# |                                                               |
# | Shared_Conv2D2 (Conv2D)   (None, 46, 24, 64)        51264     |
# |                                                               |
# | Shared_MaxPool2D2 (MaxPooli  (None, 22, 11, 64)     0         |
# | ng2D)                                                         |
# |                                                               |
# | Shared_Conv2D3 (Conv2D)   (None, 22, 11, 128)       73856     |
# |                                                               |
# | Shared_MaxPool2D3 (MaxPooli  (None, 10, 5, 128)     0         |
# | ng2D)                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  CA (Sequential)             (None, 14)                329870
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | CA_Conv2D1 (Conv2D)       (None, 10, 5, 128)        147584    |
# |                                                               |
# | CA_MaxPool2D1 (MaxPooling2D  (None, 5, 2, 128)      0         |
# | )                                                             |
# |                                                               |
# | flatten_19 (Flatten)      (None, 1280)              0         |
# |                                                               |
# | dropout_57 (Dropout)      (None, 1280)              0         |
# |                                                               |
# | CA_DenseLayer1 (Dense)    (None, 128)               163968    |
# |                                                               |
# | dropout_58 (Dropout)      (None, 128)               0         |
# |                                                               |
# | CA_DenseLayer2 (Dense)    (None, 128)               16512     |
# |                                                               |
# | dropout_59 (Dropout)      (None, 128)               0         |
# |                                                               |
# | CA_Output (Dense)         (None, 14)                1806      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 457,614
# Trainable params: 329,870
# Non-trainable params: 127,744
# _________________________________________________________________

# %%
trainxCAs = [trainxCA]
trainyCAs = [[trainyCA,LABELS_CA]]

valxCAs = [valxCA]
valyCAs = [[valyCA,LABELS_CA]]

xtypes = tuple([tf.float32]*1)
ytypes = tuple([tf.int32]*1)
traingentypes = (xtypes,ytypes)

xshapes = tuple([[FREQ_SIZE,N_MFCC,1] for i in range(1)])
yshapes = tuple([[14]])
traingenshapes = (xshapes,yshapes)

traindatasetCA = tf.data.Dataset.from_generator(maketraingenerator(trainxCAs,trainyCAs),output_types=traingentypes,output_shapes=traingenshapes)
traindatasetCA = traindatasetCA.shuffle(NUM_TRAIN_CA)
traindatasetCA = traindatasetCA.batch(BATCH_SIZE_TRAIN)
traindatasetCA = traindatasetCA.repeat(-1)
traindatasetCA = traindatasetCA.cache().prefetch(AUTOTUNE)

valdatasetCA = tf.data.Dataset.from_generator(makevalgenerator(valxCAs,valyCAs),output_types=traingentypes,output_shapes=traingenshapes)
valdatasetCA = valdatasetCA.batch(BATCH_SIZE_VAL)
valdatasetCA = valdatasetCA.cache().prefetch(AUTOTUNE)

# %%
training_callbackCA = callbacks.TensorBoard(log_dir=LOG_DIR + RUN + '-Retrain-CA')

historyCA = modelCARetrain.fit(
    x = traindatasetCA,
    validation_data = valdatasetCA,
    epochs=EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    callbacks=[training_callbackCA,earlystopping_callback,reduce_lr_callback],
    verbose=1
)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 5s 117ms/step - loss: 2.8943 - Categorical Accuracy: 0.0789 - AUC: 0.5129 - val_loss: 2.5652 - val_Categorical Accuracy: 0.1400 - val_AUC: 0.6254 - lr: 1.0000e-04
# Epoch 2/100
# 36/36 [==============================] - 4s 116ms/step - loss: 2.5782 - Categorical Accuracy: 0.1378 - AUC: 0.6155 - val_loss: 2.4336 - val_Categorical Accuracy: 0.2520 - val_AUC: 0.7415 - lr: 1.0000e-04
# Epoch 3/100
# 36/36 [==============================] - 4s 115ms/step - loss: 2.4396 - Categorical Accuracy: 0.1833 - AUC: 0.6893 - val_loss: 2.2861 - val_Categorical Accuracy: 0.2920 - val_AUC: 0.8061 - lr: 1.0000e-04
# Epoch 4/100
# 36/36 [==============================] - 4s 116ms/step - loss: 2.2851 - Categorical Accuracy: 0.2333 - AUC: 0.7502 - val_loss: 2.1538 - val_Categorical Accuracy: 0.3420 - val_AUC: 0.8327 - lr: 1.0000e-04
# Epoch 5/100
# 36/36 [==============================] - 4s 117ms/step - loss: 2.0705 - Categorical Accuracy: 0.3033 - AUC: 0.8170 - val_loss: 1.9788 - val_Categorical Accuracy: 0.3720 - val_AUC: 0.8527 - lr: 1.0000e-04
# Epoch 6/100
# 36/36 [==============================] - 4s 116ms/step - loss: 1.9528 - Categorical Accuracy: 0.3222 - AUC: 0.8412 - val_loss: 1.8429 - val_Categorical Accuracy: 0.4320 - val_AUC: 0.8799 - lr: 1.0000e-04
# Epoch 7/100
# 36/36 [==============================] - 4s 117ms/step - loss: 1.8153 - Categorical Accuracy: 0.3611 - AUC: 0.8680 - val_loss: 1.7772 - val_Categorical Accuracy: 0.4240 - val_AUC: 0.8832 - lr: 1.0000e-04
# Epoch 8/100
# 36/36 [==============================] - 4s 116ms/step - loss: 1.6855 - Categorical Accuracy: 0.3989 - AUC: 0.8916 - val_loss: 1.6759 - val_Categorical Accuracy: 0.4580 - val_AUC: 0.8959 - lr: 1.0000e-04
# Epoch 9/100
# 36/36 [==============================] - 4s 117ms/step - loss: 1
100
# 36/36 [==============================] - 4s 119ms/step - loss: 0.8242 - Categorical Accuracy: 0.6911 - AUC: 0.9754 - val_loss: 1.2136 - val_Categorical Accuracy: 0.5720 - val_AUC: 0.9406 - lr: 1.0000e-04
# Epoch 24/100
# 36/36 [==============================] - ETA: 0s - loss: 0.7350 - Categorical Accuracy: 0.7589 - AUC: 0.9816
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 36/36 [==============================] - 4s 118ms/step - loss: 0.7350 - Categorical Accuracy: 0.7589 - AUC: 0.9816 - val_loss: 1.2005 - val_Categorical Accuracy: 0.5780 - val_AUC: 0.9415 - lr: 1.0000e-04
# Epoch 25/100
# 36/36 [==============================] - 4s 119ms/step - loss: 0.7042 - Categorical Accuracy: 0.7600 - AUC: 0.9827 - val_loss: 1.1728 - val_Categorical Accuracy: 0.6080 - val_AUC: 0.9442 - lr: 2.0000e-05
# Epoch 26/100
# 36/36 [==============================] - 4s 119ms/step - loss: 0.7068 - Categorical Accuracy: 0.7633 - AUC: 0.9823 - val_loss: 1.1743 - val_Categorical Accuracy: 0.6020 - val_AUC: 0.9423 - lr: 2.0000e-05
# Epoch 27/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6960 - Categorical Accuracy: 0.7656 - AUC: 0.9836
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1e-05.
# 36/36 [==============================] - 4s 119ms/step - loss: 0.6960 - Categorical Accuracy: 0.7656 - AUC: 0.9836 - val_loss: 1.1732 - val_Categorical Accuracy: 0.6000 - val_AUC: 0.9441 - lr: 2.0000e-05
# Epoch 28/100
# 36/36 [==============================] - 4s 119ms/step - loss: 0.6879 - Categorical Accuracy: 0.7711 - AUC: 0.9838 - val_loss: 1.1638 - val_Categorical Accuracy: 0.6100 - val_AUC: 0.9450 - lr: 1.0000e-05
# Epoch 29/100
# 36/36 [==============================] - 4s 123ms/step - loss: 0.6530 - Categorical Accuracy: 0.7767 - AUC: 0.9858 - val_loss: 1.1581 - val_Categorical Accuracy: 0.6140 - val_AUC: 0.9451 - lr: 1.0000e-05
# Epoch 30/100
# 36/36 [==============================] - 5s 129ms/step - loss: 0.6762 - Categorical Accuracy: 0.7778 - AUC: 0.9844 - val_loss: 1.1623 - val_Categorical Accuracy: 0.6200 - val_AUC: 0.9439 - lr: 1.0000e-05
# Epoch 31/100
# 36/36 [==============================] - 5s 129ms/step - loss: 0.6664 - Categorical Accuracy: 0.7789 - AUC: 0.9849 - val_loss: 1.1675 - val_Categorical Accuracy: 0.6100 - val_AUC: 0.9435 - lr: 1.0000e-05
# Epoch 32/100
# 36/36 [==============================] - 5s 130ms/step - loss: 0.6714 - Categorical Accuracy: 0.7767 - AUC: 0.9844 - val_loss: 1.1668 - val_Categorical Accuracy: 0.6080 - val_AUC: 0.9431 - lr: 1.0000e-05
# Epoch 33/100
# 36/36 [==============================] - 5s 130ms/step - loss: 0.6641 - Categorical Accuracy: 0.7733 - AUC: 0.9850 - val_loss: 1.1571 - val_Categorical Accuracy: 0.6100 - val_AUC: 0.9452 - lr: 1.0000e-05
# Epoch 34/100
# 36/36 [==============================] - 5s 130ms/step - loss: 0.6304 - Categorical Accuracy: 0.8022 - AUC: 0.9872 - val_loss: 1.1573 - val_Categorical Accuracy: 0.6180 - val_AUC: 0.9447 - lr: 1.0000e-05
# Epoch 35/100
# 36/36 [==============================] - 5s 129ms/step - loss: 0.6118 - Categorical Accuracy: 0.7978 - AUC: 0.9873 - val_loss: 1.1672 - val_Categorical Accuracy: 0.6120 - val_AUC: 0.9422 - lr: 1.0000e-05
# Epoch 36/100
# 36/36 [==============================] - 5s 130ms/step - loss: 0.6157 - Categorical Accuracy: 0.8122 - AUC: 0.9870 - val_loss: 1.1566 - val_Categorical Accuracy: 0.6160 - val_AUC: 0.9454 - lr: 1.0000e-05
# Epoch 37/100
# 36/36 [==============================] - 5s 131ms/step - loss: 0.6645 - Categorical Accuracy: 0.7767 - AUC: 0.9851 - val_loss: 1.1588 - val_Categorical Accuracy: 0.6160 - val_AUC: 0.9426 - lr: 1.0000e-05
# Epoch 38/100
# 36/36 [==============================] - 5s 130ms/step - loss: 0.6686 - Categorical Accuracy: 0.7644 - AUC: 0.9843 - val_loss: 1.1537 - val_Categorical Accuracy: 0.6120 - val_AUC: 0.9443 - lr: 1.0000e-05
# Epoch 39/100
# 36/36 [==============================] - 5s 130ms/step - loss: 0.6356 - Categorical Accuracy: 0.7944 - AUC: 0.9859 - val_loss: 1.1561 - val_Categorical Accuracy: 0.6140 - val_AUC: 0.9432 - lr: 1.0000e-05
# Epoch 40/100
# 36/36 [==============================] - 5s 130ms/step - loss: 0.6269 - Categorical Accuracy: 0.7833 - AUC: 0.9860 - val_loss: 1.1572 - val_Categorical Accuracy: 0.6160 - val_AUC: 0.9443 - lr: 1.0000e-05
# Epoch 41/100
# 36/36 [==============================] - 5s 131ms/step - loss: 0.6233 - Categorical Accuracy: 0.8022 - AUC: 0.9869 - val_loss: 1.1559 - val_Categorical Accuracy: 0.6080 - val_AUC: 0.9444 - lr: 1.0000e-05
# Epoch 42/100
# 36/36 [==============================] - 5s 131ms/step - loss: 0.6095 - Categorical Accuracy: 0.7933 - AUC: 0.9873 - val_loss: 1.1553 - val_Categorical Accuracy: 0.6180 - val_AUC: 0.9434 - lr: 1.0000e-05
# Epoch 43/100
# 36/36 [==============================] - 5s 130ms/step - loss: 0.6135 - Categorical Accuracy: 0.7878 - AUC: 0.9878 - val_loss: 1.1520 - val_Categorical Accuracy: 0.6040 - val_AUC: 0.9448 - lr: 1.0000e-05
# Epoch 44/100
# 36/36 [==============================] - 5s 131ms/step - loss: 0.6256 - Categorical Accuracy: 0.7878 - AUC: 0.9862 - val_loss: 1.1551 - val_Categorical Accuracy: 0.6060 - val_AUC: 0.9439 - lr: 1.0000e-05
# Epoch 45/100
# 36/36 [==============================] - 5s 131ms/step - loss: 0.6011 - Categorical Accuracy: 0.8056 - AUC: 0.9876 - val_loss: 1.1524 - val_Categorical Accuracy: 0.6140 - val_AUC: 0.9441 - lr: 1.0000e-05
# Epoch 46/100
# 36/36 [==============================] - 5s 131ms/step - loss: 0.6062 - Categorical Accuracy: 0.8044 - AUC: 0.9883 - val_loss: 1.1547 - val_Categorical Accuracy: 0.6140 - val_AUC: 0.9442 - lr: 1.0000e-05
# Epoch 47/100
# 36/36 [==============================] - 5s 132ms/step - loss: 0.6053 - Categorical Accuracy: 0.8000 - AUC: 0.9875 - val_loss: 1.1548 - val_Categorical Accuracy: 0.6060 - val_AUC: 0.9433 - lr: 1.0000e-05
# Epoch 48/100
# 36/36 [==============================] - 5s 132ms/step - loss: 0.5722 - Categorical Accuracy: 0.8156 - AUC: 0.9896 - val_loss: 1.1531 - val_Categorical Accuracy: 0.6120 - val_AUC: 0.9442 - lr: 1.0000e-05

# %%
modelCARetrain.evaluate(testdatasetCA)
# Out:
# 250/250 [==============================] - 3s 11ms/step - loss: 1.3291 - Categorical Accuracy: 0.5120 - AUC: 0.9304
# [1.3291032314300537, 0.5120000243186951, 0.9304239749908447]
